# %% [markdown]
# <a href="https://colab.research.google.com/github/luizftoledo/datafixers/blob/main/candidatos_doadores_e_multas_ambientais_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importando bibliotecas necessárias
# !pip install jsonschema==3.2
import pandas as pd
import ssl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting jsonschema==3.2
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.4 MB/s
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema==3.2) (22.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema==3.2) (0.18.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema==3.2) (4.12.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema==3.2) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from jsonschema==3.2) (57.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->jsonschema==3.2) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->jsonschema==3.2) (3.8.1)
# Installing collected packages: jsonschema
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.3.3
#     Uninstalling jsonschema-4.3.3:
#       Successfully uninstalled jsonschema-4.3.3
# Successfully installed jsonschema-3.2.0

# %%
# importando os dados de multa. todos foram baixados aqui: https://servicos.ibama.gov.br/ctf/publico/areasembargadas/ConsultaPublicaAreasEmbargadas.php
# se preferir, acesse todas as planilhas já baixadas aqui: https://drive.google.com/drive/folders/1UGMtjMEwa01bj8gX1gtzYvvQxmkHHZr6?usp=sharing
df0 = pd.read_html('/content/drive/MyDrive/ibama fines/2005.xls', decimal=',', thousands='.')[0]
df1 = pd.read_html('/content/drive/MyDrive/ibama fines/2006.xls', decimal=',', thousands='.')[0]
df2 = pd.read_html('/content/drive/MyDrive/ibama fines/2007.xls', decimal=',', thousands='.')[0]
df3 = pd.read_html('/content/drive/MyDrive/ibama fines/2008.xls', decimal=',', thousands='.')[0]
df4 = pd.read_html('/content/drive/MyDrive/ibama fines/2009.xls', decimal=',', thousands='.')[0]
df5 = pd.read_html('/content/drive/MyDrive/ibama fines/2010.xls', decimal=',', thousands='.')[0]
df6 = pd.read_html('/content/drive/MyDrive/ibama fines/2011.xls', decimal=',', thousands='.')[0]
df7 = pd.read_html('/content/drive/MyDrive/ibama fines/2012.xls', decimal=',', thousands='.')[0]
df8 = pd.read_html('/content/drive/MyDrive/ibama fines/2013.xls', decimal=',', thousands='.')[0]
df9 = pd.read_html('/content/drive/MyDrive/ibama fines/2014.xls', decimal=',', thousands='.')[0]
df10 = pd.read_html('/content/drive/MyDrive/ibama fines/2015.xls', decimal=',', thousands='.')[0]
df11 = pd.read_html('/content/drive/MyDrive/ibama fines/2016.xls', decimal=',', thousands='.')[0]
df12 = pd.read_html('/content/drive/MyDrive/ibama fines/2017.xls', decimal=',', thousands='.')[0]
df13 = pd.read_html('/content/drive/MyDrive/ibama fines/2018.xls', decimal=',', thousands='.')[0]
df14 = pd.read_html('/content/drive/MyDrive/ibama fines/2019.xls', decimal=',', thousands='.')[0]
df15 = pd.read_html('/content/drive/MyDrive/ibama fines/2020.xls', decimal=',', thousands='.')[0]
df16 = pd.read_html('/content/drive/MyDrive/ibama fines/2021.xls', decimal=',', thousands='.')[0]
df17 = pd.read_html('/content/drive/MyDrive/ibama fines/2022_ate_8_setembro.xls', decimal=',', thousands='.')[0]

# %%
# arrumando nomes das colunas
df0.columns = df0.loc[0]
df0 = df0.drop(0)
df1.columns = df1.loc[0]
df1 = df1.drop(0)
df2.columns = df2.loc[0]
df2 = df2.drop(0)
df3.columns = df3.loc[0]
df3 = df3.drop(0)
df4.columns = df4.loc[0]
df4 = df4.drop(0)
df5.columns = df5.loc[0]
df5 = df5.drop(0)
df6.columns = df6.loc[0]
df6 = df6.drop(0)
df7.columns = df7.loc[0]
df7 = df7.drop(0)
df8.columns = df8.loc[0]
df8 = df8.drop(0)
df9.columns = df9.loc[0]
df9 = df9.drop(0)
df10.columns = df10.loc[0]
df10 = df10.drop(0)
df11.columns = df11.loc[0]
df11 = df11.drop(0)
df12.columns = df12.loc[0]
df12 = df12.drop(0)
df13.columns = df13.loc[0]
df13 = df13.drop(0)
df14.columns = df14.loc[0]
df14 = df14.drop(0)
df15.columns = df15.loc[0]
df15 = df15.drop(0)
df16.columns = df16.loc[0]
df16 = df16.drop(0)
df17.columns = df17.loc[0]
df17 = df17.drop(0)

# %%
# unificando as planilhas com os dados de multas de 2005 a 2022
df_aut_ffox = pd.concat([df0, df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17])
df_aut_ffox.head(1)
# Out:
# 0     Nº Tipo Infracao Data Infração Bioma Estado   Município     CPF ou CNPJ  \
# 1  21437         Flora    22/08/2005   NaN   ACRE  ACRELANDIA  282.495.187-72
#
# 0             Nome Autuado Nº A.I. Série A.I. Valor Multa  \
# 1  ADWALTER COSTA SILVEIRA  526322          D     1200.00
#
# 0           Nº Processo              Status Débito Sanções Aplicadas
# 1  02002.000813/2005-28  Quitado. Baixa automática               NaN

# %%
# vamos remover as multas que aparecem sem nenhum valor / valor nulo 
naonulos = df_aut_ffox[df_aut_ffox['Valor Multa'].notna()]


# vamos transformar os valores em integer
naonulos['Valor Multa'] = naonulos['Valor Multa'].astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# vamos salvar o arquivo em csv
naonulos.to_csv('naonulos.csv', index=False)
naonulos = pd.read_csv('naonulos.csv')
naonulos.head(1)
# Out:
#       Nº Tipo Infracao Data Infração Bioma Estado   Município     CPF ou CNPJ  \
# 0  21437         Flora    22/08/2005   NaN   ACRE  ACRELANDIA  282.495.187-72
#
#               Nome Autuado Nº A.I. Série A.I.  Valor Multa  \
# 0  ADWALTER COSTA SILVEIRA  526322          D       1200.0
#
#             Nº Processo              Status Débito Sanções Aplicadas
# 0  02002.000813/2005-28  Quitado. Baixa automática               NaN

# %%
# arrumando colunas
naonulos.columns = naonulos.columns.str.lower().str.replace(' ', '_')
naonulos.columns = naonulos.columns.str.replace('º', '')
naonulos.columns = naonulos.columns.str.replace('í', 'i')
naonulos.columns = naonulos.columns.str.replace('ã', 'a')
naonulos.columns = naonulos.columns.str.replace('é', 'e')
naonulos.columns = naonulos.columns.str.replace('ç', 'c')
naonulos.columns = naonulos.columns.str.replace('õ', 'o')

# %%
# checando os nomes das colunas
naonulos.columns
# Out:
# Index(['n', 'tipo_infracao', 'data_infracao', 'bioma', 'estado', 'municipio',
#        'cpf_ou_cnpj', 'nome_autuado', 'n_a.i.', 'serie_a.i.', 'valor_multa',
#        'n_processo', 'status_debito', 'sancoes_aplicadas'],
#       dtype='object')

# %%
#criando coluna de ano e transformando a coluna de data em formato datetime

naonulos.data_infracao = pd.to_datetime(naonulos.data_infracao)
naonulos['ano'] = pd.DatetimeIndex(naonulos['data_infracao']).year

naonulos.head(1)
# Out:
#        n tipo_infracao data_infracao bioma estado   municipio     cpf_ou_cnpj  \
# 0  21437         Flora    2005-08-22   NaN   ACRE  ACRELANDIA  282.495.187-72
#
#               nome_autuado  n_a.i. serie_a.i.  valor_multa  \
# 0  ADWALTER COSTA SILVEIRA  526322          D       1200.0
#
#              n_processo              status_debito sancoes_aplicadas   ano
# 0  02002.000813/2005-28  Quitado. Baixa automática               NaN  2005

# %%
# quantidade de dados - ano a ano 
naonulos.ano.value_counts()
# Out:
# 2005    33866
# 2008    29743
# 2007    27201
# 2006    25591
# 2009    21982
# 2010    20354
# 2011    19894
# 2012    18883
# 2016    17511
# 2015    16900
# 2017    15936
# 2013    15720
# 2014    15521
# 2018    15337
# 2021    12873
# 2019    12794
# 2020    11316
# 2022     9155
# Name: ano, dtype: int64

# %%
naonulos.ano.unique()
# Out:
# array([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019, 2020, 2021, 2022])

# %%
# arrumar/unificar nome do estado
naonulos['estado'] = naonulos['estado'].replace(['PA'],'PARA')
naonulos['estado'] = naonulos['estado'].replace(['SP'],'SAO PAULO')
naonulos['estado'] = naonulos['estado'].replace(['SP'],'SAO PAULO')
naonulos['estado'] = naonulos['estado'].replace(['DF'],'DISTRITO FEDERAL')
naonulos['estado'] = naonulos['estado'].replace(['RJ'],'RIO DE JANEIRO')
naonulos['estado'] = naonulos['estado'].replace(['MG'],'MINAS GERAIS')
naonulos['estado'] = naonulos['estado'].replace(['AM'],'AMAZONAS')
naonulos['estado'] = naonulos['estado'].replace(['MG'],'MINAS GERAIS')
naonulos['estado'] = naonulos['estado'].replace(['ES'],'ESPIRITO SANTO')
naonulos['estado'] = naonulos['estado'].replace(['PR'],'PARANA')
naonulos['estado'] = naonulos['estado'].replace(['RS'],'RIO GRANDE DO SUL')
naonulos['estado'] = naonulos['estado'].replace(['SE'],'SERGIPE')
naonulos['estado'] = naonulos['estado'].replace(['AC'],'ACRE')
naonulos['estado'] = naonulos['estado'].replace(['AP'],'AMAPA')
naonulos['estado'] = naonulos['estado'].replace(['BA'],'BAHIA')
naonulos['estado'] = naonulos['estado'].replace(['CE'],'CEARA')
naonulos['estado'] = naonulos['estado'].replace(['GO'],'GOIAS')
naonulos['estado'] = naonulos['estado'].replace(['MS'],'MATO GROSSO DO SUL')
naonulos['estado'] = naonulos['estado'].replace(['RO'],'RONDONIA')
naonulos['estado'] = naonulos['estado'].replace(['RR'],'RORAIMA')
naonulos['estado'] = naonulos['estado'].replace(['SC'],'SANTA CATARINA')
naonulos['estado'] = naonulos['estado'].replace(['TO'],'TOCANTINS')
naonulos['estado'] = naonulos['estado'].replace(['AL'],'ALAGOAS')
naonulos['estado'] = naonulos['estado'].replace(['MG'],'MINAS GERAIS')
naonulos['estado'] = naonulos['estado'].replace(['MA'],'MARANHAO')
naonulos['estado'] = naonulos['estado'].replace(['PB'],'PARAIBA')
naonulos['estado'] = naonulos['estado'].replace(['RN'],'RIO GRANDE DO NORTE')
naonulos['estado'] = naonulos['estado'].replace(['PI'],'PIAUI')
naonulos['estado'] = naonulos['estado'].replace(['MT'],'MATO GROSSO')
naonulos['estado'] = naonulos['estado'].replace(['PE'],'PERNAMBUCO')

# %%
naonulos.head(1)
# Out:
#        n tipo_infracao data_infracao bioma estado   municipio     cpf_ou_cnpj  \
# 0  21437         Flora    2005-08-22   NaN   ACRE  ACRELANDIA  282.495.187-72
#
#               nome_autuado  n_a.i. serie_a.i.  valor_multa  \
# 0  ADWALTER COSTA SILVEIRA  526322          D       1200.0
#
#              n_processo              status_debito sancoes_aplicadas   ano
# 0  02002.000813/2005-28  Quitado. Baixa automática               NaN  2005

# %%
naonulos.cpf_ou_cnpj.head(15)
# Out:
# 0     282.495.187-72
# 1     408.954.759-87
# 2     164.524.372-91
# 3     205.968.719-53
# 4     676.402.902-44
# 5     091.282.712-20
# 6     391.178.982-34
# 7     126.212.935-49
# 8     434.872.892-53
# 9     338.774.595-87
# 10    576.298.702-72
# 11    532.812.502-97
# 12    196.965.152-00
# 13    629.359.172-00
# 14    703.023.162-72
# Name: cpf_ou_cnpj, dtype: object

# %%
# remover pontos e barras do cpf/cnpj das empresas e pessoas (para depois poder cruzar com outros dados)
naonulos.cpf_ou_cnpj = naonulos.cpf_ou_cnpj.str.replace('.','')
naonulos.cpf_ou_cnpj = naonulos.cpf_ou_cnpj.str.replace('-','')
naonulos.cpf_ou_cnpj = naonulos.cpf_ou_cnpj.str.replace('/','')

naonulos.cpf_ou_cnpj.head(15)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# 0     28249518772
# 1     40895475987
# 2     16452437291
# 3     20596871953
# 4     67640290244
# 5     09128271220
# 6     39117898234
# 7     12621293549
# 8     43487289253
# 9     33877459587
# 10    57629870272
# 11    53281250297
# 12    19696515200
# 13    62935917200
# 14    70302316272
# Name: cpf_ou_cnpj, dtype: object

# %%
# agora vamos carregar a base de dados de CANDIDATOS

cand22 = pd.read_csv('/content/drive/MyDrive/ibama fines/consulta_cand_2022_BRASIL.csv', sep=';', encoding='latin1', converters={'NR_CPF_CANDIDATO': str})

cand22.head(1)
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  08/09/2022   13:05:22         2022                2  ELEIÇÃO ORDINÁRIA
#
#    NR_TURNO  CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  \
# 0         1         546  Eleições Gerais Estaduais 2022  02/10/2022
#
#   TP_ABRANGENCIA  ...          NR_PROCESSO CD_SITUACAO_CANDIDATO_PLEITO  \
# 0       ESTADUAL  ...  6008896420226130000                           -1
#
#   DS_SITUACAO_CANDIDATO_PLEITO  CD_SITUACAO_CANDIDATO_URNA  \
# 0                       #NULO#                          -1
#
#   DS_SITUACAO_CANDIDATO_URNA  ST_CANDIDATO_INSERIDO_URNA  \
# 0                     #NULO#                         SIM
#
#    NM_TIPO_DESTINACAO_VOTOS CD_SITUACAO_CANDIDATO_TOT  \
# 0                    #NULO#                        -1
#
#   DS_SITUACAO_CANDIDATO_TOT ST_PREST_CONTAS
# 0                    #NULO#               N
#
# [1 rows x 71 columns]

# %%
# mostrar todas as colunas da base
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:,}'.format)

# %%
cand22.NR_CPF_CANDIDATO
# Out:
# 0        07225196642
# 1        02144647500
# 2        10009728368
# 3        32822820368
# 4        23557770559
#             ...
# 29086    25993681896
# 29087    41533755272
# 29088    93260326804
# 29089    31472249100
# 29090    06014216120
# Name: NR_CPF_CANDIDATO, Length: 29091, dtype: object

# %%
multas_candidatos = naonulos.merge(cand22, left_on='cpf_ou_cnpj', right_on='NR_CPF_CANDIDATO')

multas_candidatos
# Out:
#          n       tipo_infracao data_infracao     bioma            estado  \
# 0     3106  Controle ambiental    2005-08-03       NaN             CEARA
# 1    13149               Fauna    2005-04-28       NaN  DISTRITO FEDERAL
# 2     4403  Controle ambiental    2005-08-12       NaN             GOIAS
# 3    14017  Controle ambiental    2005-06-12       NaN             GOIAS
# 4    25386               Flora    2005-12-15       NaN          MARANHAO
# ..     ...                 ...           ...       ...               ...
# 348    754              Outras    2022-06-04  Amazonia       MATO GROSSO
# 349    755              Outras    2022-06-04  Amazonia       MATO GROSSO
# 350   5984               Flora    2022-02-18  Amazonia          RONDONIA
# 351   6281               Flora    2022-02-18  Amazonia          RONDONIA
# 352   4580               Flora    2022-02-18  Amazonia          RONDONIA
#
#         municipio  cpf_ou_cnpj                       nome_autuado    n_a.i.  \
# 0          FORTIM  32297009372       RAIMUNDO ANSELMO LIMA MORORÓ    294486
# 1        BRASILIA  51630427187              AURENI BRUZ DE ARAUJO    411557
# 2    CALDAS NOVAS  52141314100  EVANDO MAGAL ABADIA CORREIA SILVA    485161
# 3    CALDAS NOVAS  13205285115                  MAGDA MOFATTO HON    431876
# 4      CHAPADINHA  59577126715        MAGNO AUGUSTO BACELAR NUNES    130508
# ..            ...          ...                                ...       ...
# 348          Vera  24666246053                     ANTONIO GALVAN  YBK9MJMG
# 349          Vera  24666246053                     ANTONIO GALVAN  YBK9MJMG
# 350   PORTO VELHO  86932667800            JOSE EURIPEDES CLEMENTE  Q607ZXHO
# 351   PORTO VELHO  86932667800            JOSE EURIPEDES CLEMENTE  9MS7IC5Z
# 352   PORTO VELHO  86932667800            JOSE EURIPEDES CLEMENTE  OZWY2XVQ
#
#     serie_a.i.  valor_multa            n_processo  \
# 0            D     50,000.0  02007.000638/2005-29
# 1            D        500.0  02008.000252/2005-15
# 2            D      5,000.0  02010.003681/2005-97
# 3            D      5,000.0  02010.003651/2005-81
# 4            D      6,000.0  02012.002328/2005-70
# ..         ...          ...                   ...
# 348        NaN  1,510,500.0  02013.001124/2022-11
# 349        NaN  1,510,500.0  02013.001124/2022-11
# 350        NaN  1,280,000.0  02001.005452/2022-17
# 351        NaN    435,000.0  02001.007284/2022-02
# 352        NaN    220,000.0  02001.005749/2022-82
#
#                                          status_debito  \
# 0              Rescisão de parcelamento extra judicial
# 1                                             Ajuizado
# 2    Quitado por Parcelamento (Leis 12249, 12865, 1...
# 3                                 Em cobrança judicial
# 4                            Quitado. Baixa automática
# ..                                                 ...
# 348                                            Lavrado
# 349                                            Lavrado
# 350                   Para homologação/prazo de defesa
# 351                   Para homologação/prazo de defesa
# 352                   Para homologação/prazo de defesa
#
#                                      sancoes_aplicadas   ano  DT_GERACAO  \
# 0         70 64 Lei, 9605/98, 51 2º Decreto, 3179/1999  2005  08/09/2022
# 1       11 2º - Decreto, 3179/1999, 70 72 Lei, 9605/98  2005  08/09/2022
# 2    70 38/60 Lei, 9605/98, 44 2º Decreto, 3179/199...  2005  08/09/2022
# 3    70 38/60 Lei, 9605/98, 44 2º Decreto, 3179/199...  2005  08/09/2022
# 4    70 19 Lei, Lei 9.605/98, 38 2º Decreto, 3179/1999  2005  08/09/2022
# ..                                                 ...   ...         ...
# 348  Fazer funcionar atividade, sendo aeródromo Civ...  2022  08/09/2022
# 349  Fazer funcionar atividade, sendo aeródromo Civ...  2022  08/09/2022
# 350                              50 Decreto, 6514/2008  2022  08/09/2022
# 351                              50 Decreto, 6514/2008  2022  08/09/2022
# 352                              50 Decreto, 6514/2008  2022  08/09/2022
#
#     HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  NR_TURNO  \
# 0     13:05:22         2022                2  ELEIÇÃO ORDINÁRIA         1
# 1     13:05:22         2022                2  ELEIÇÃO ORDINÁRIA         1
# 2     13:05:22         2022                2  ELEIÇÃO ORDINÁRIA         1
# 3     13:05:22         2022                2  ELEIÇÃO ORDINÁRIA         1
# 4     13:05:22         2022                2  ELEIÇÃO ORDINÁRIA         1
# ..         ...          ...              ...                ...       ...
# 348   13:05:22         2022                2  ELEIÇÃO ORDINÁRIA         1
# 349   13:05:22         2022                2  ELEIÇÃO ORDINÁRIA         1
# 350   13:05:22         2022                2  ELEIÇÃO ORDINÁRIA         1
# 351   13:05:22         2022                2  ELEIÇÃO ORDINÁRIA         1
# 352   13:05:22         2022                2  ELEIÇÃO ORDINÁRIA         1
#
#      CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO TP_ABRANGENCIA  \
# 0           546  Eleições Gerais Estaduais 2022  02/10/2022       ESTADUAL
# 1           546  Eleições Gerais Estaduais 2022  02/10/2022       ESTADUAL
# 2           546  Eleições Gerais Estaduais 2022  02/10/2022       ESTADUAL
# 3           546  Eleições Gerais Estaduais 2022  02/10/2022       ESTADUAL
# 4           546  Eleições Gerais Estaduais 2022  02/10/2022       ESTADUAL
# ..          ...                             ...         ...            ...
# 348         546  Eleições Gerais Estaduais 2022  02/10/2022       ESTADUAL
# 349         546  Eleições Gerais Estaduais 2022  02/10/2022       ESTADUAL
# 350         546  Eleições Gerais Estaduais 2022  02/10/2022       ESTADUAL
# 351         546  Eleições Gerais Estaduais 2022  02/10/2022       ESTADUAL
# 352         546  Eleições Gerais Estaduais 2022  02/10/2022       ESTADUAL
#
#     SG_UF SG_UE             NM_UE  CD_CARGO            DS_CARGO  SQ_CANDIDATO  \
# 0      CE    CE             CEARÁ         6    DEPUTADO FEDERAL   60001634107
# 1      DF    DF  DISTRITO FEDERAL         8  DEPUTADO DISTRITAL   70001612587
# 2      GO    GO             GOIÁS         6    DEPUTADO FEDERAL   90001650886
# 3      GO    GO             GOIÁS         6    DEPUTADO FEDERAL   90001652511
# 4      MA    MA          MARANHÃO         6    DEPUTADO FEDERAL  100001608079
# ..    ...   ...               ...       ...                 ...           ...
# 348    MT    MT       MATO GROSSO         5             SENADOR  110001621186
# 349    MT    MT       MATO GROSSO         5             SENADOR  110001621186
# 350    RO    RO          RONDÔNIA         6    DEPUTADO FEDERAL  220001605553
# 351    RO    RO          RONDÔNIA         6    DEPUTADO FEDERAL  220001605553
# 352    RO    RO          RONDÔNIA         6    DEPUTADO FEDERAL  220001605553
#
#      NR_CANDIDATO                       NM_CANDIDATO NM_URNA_CANDIDATO  \
# 0            7022       RAIMUNDO ANSELMO LIMA MORORO    ANSELMO MORORÓ
# 1           28800      AURENI BRAZ VILANOVA DE SOUSA         NENA BRAZ
# 2            5111  EVANDO MAGAL ABADIA CORREIA SILVA             MAGAL
# 3            2222                  MAGDA MOFATTO HON     MAGDA MOFATTO
# 4            1110        MAGNO AUGUSTO BACELAR NUNES  DR MAGNO BACELAR
# ..            ...                                ...               ...
# 348           144                     ANTONIO GALVAN    ANTÔNIO GALVAN
# 349           144                     ANTONIO GALVAN    ANTÔNIO GALVAN
# 350          4429            JOSÉ EURIPEDES CLEMENTE            LEBRÃO
# 351          4429            JOSÉ EURIPEDES CLEMENTE            LEBRÃO
# 352          4429            JOSÉ EURIPEDES CLEMENTE            LEBRÃO
#
#     NM_SOCIAL_CANDIDATO NR_CPF_CANDIDATO        NM_EMAIL  \
# 0                #NULO#      32297009372  NÃO DIVULGÁVEL
# 1                #NULO#      51630427187  NÃO DIVULGÁVEL
# 2                #NULO#      52141314100  NÃO DIVULGÁVEL
# 3                #NULO#      13205285115  NÃO DIVULGÁVEL
# 4                #NULO#      59577126715  NÃO DIVULGÁVEL
# ..                  ...              ...             ...
# 348              #NULO#      24666246053  NÃO DIVULGÁVEL
# 349              #NULO#      24666246053  NÃO DIVULGÁVEL
# 350              #NULO#      86932667800  NÃO DIVULGÁVEL
# 351              #NULO#      86932667800  NÃO DIVULGÁVEL
# 352              #NULO#      86932667800  NÃO DIVULGÁVEL
#
#      CD_SITUACAO_CANDIDATURA DS_SITUACAO_CANDIDATURA  \
# 0                         12                    APTO
# 1                         12                    APTO
# 2                         12                    APTO
# 3                         12                    APTO
# 4                          1              CADASTRADO
# ..                       ...                     ...
# 348                       12                    APTO
# 349                       12                    APTO
# 350                       12                    APTO
# 351                       12                    APTO
# 352                       12                    APTO
#
#      CD_DETALHE_SITUACAO_CAND DS_DETALHE_SITUACAO_CAND    TP_AGREMIACAO  \
# 0                           2                 DEFERIDO  PARTIDO ISOLADO
# 1                           2                 DEFERIDO  PARTIDO ISOLADO
# 2                           2                 DEFERIDO  PARTIDO ISOLADO
# 3                           2                 DEFERIDO  PARTIDO ISOLADO
# 4                           8    AGUARDANDO JULGAMENTO  PARTIDO ISOLADO
# ..                        ...                      ...              ...
# 348                         2                 DEFERIDO  PARTIDO ISOLADO
# 349                         2                 DEFERIDO  PARTIDO ISOLADO
# 350                         2                 DEFERIDO  PARTIDO ISOLADO
# 351                         2                 DEFERIDO  PARTIDO ISOLADO
# 352                         2                 DEFERIDO  PARTIDO ISOLADO
#
#      NR_PARTIDO SG_PARTIDO                                NM_PARTIDO  \
# 0            70     AVANTE                                    AVANTE
# 1            28       PRTB  PARTIDO RENOVADOR TRABALHISTA BRASILEIRO
# 2            51   PATRIOTA                                  PATRIOTA
# 3            22         PL                           PARTIDO LIBERAL
# 4            11         PP                             PROGRESSISTAS
# ..          ...        ...                                       ...
# 348          14        PTB            PARTIDO TRABALHISTA BRASILEIRO
# 349          14        PTB            PARTIDO TRABALHISTA BRASILEIRO
# 350          44      UNIÃO                              UNIÃO BRASIL
# 351          44      UNIÃO                              UNIÃO BRASIL
# 352          44      UNIÃO                              UNIÃO BRASIL
#
#      NR_FEDERACAO NM_FEDERACAO SG_FEDERACAO DS_COMPOSICAO_FEDERACAO  \
# 0              -1       #NULO#       #NULO#                  #NULO#
# 1              -1       #NULO#       #NULO#                  #NULO#
# 2              -1       #NULO#       #NULO#                  #NULO#
# 3              -1       #NULO#       #NULO#                  #NULO#
# 4              -1       #NULO#       #NULO#                  #NULO#
# ..            ...          ...          ...                     ...
# 348            -1       #NULO#       #NULO#                  #NULO#
# 349            -1       #NULO#       #NULO#                  #NULO#
# 350            -1       #NULO#       #NULO#                  #NULO#
# 351            -1       #NULO#       #NULO#                  #NULO#
# 352            -1       #NULO#       #NULO#                  #NULO#
#
#      SQ_COLIGACAO     NM_COLIGACAO DS_COMPOSICAO_COLIGACAO  CD_NACIONALIDADE  \
# 0     60001682571  PARTIDO ISOLADO                  AVANTE                 1
# 1     70001681623  PARTIDO ISOLADO                    PRTB                 1
# 2     90001683329  PARTIDO ISOLADO                PATRIOTA                 1
# 3     90001683394  PARTIDO ISOLADO                      PL                 1
# 4    100001681362  PARTIDO ISOLADO                      PP                 1
# ..            ...              ...                     ...               ...
# 348  110001682249  PARTIDO ISOLADO                     PTB                 1
# 349  110001682249  PARTIDO ISOLADO                     PTB                 1
# 350  220001681061  PARTIDO ISOLADO                   UNIÃO                 1
# 351  220001681061  PARTIDO ISOLADO                   UNIÃO                 1
# 352  220001681061  PARTIDO ISOLADO                   UNIÃO                 1
#
#     DS_NACIONALIDADE SG_UF_NASCIMENTO  CD_MUNICIPIO_NASCIMENTO  \
# 0    BRASILEIRA NATA               CE                       -3
# 1    BRASILEIRA NATA               DF                       -3
# 2    BRASILEIRA NATA               GO                       -3
# 3    BRASILEIRA NATA               SP                       -3
# 4    BRASILEIRA NATA               MA                       -3
# ..               ...              ...                      ...
# 348  BRASILEIRA NATA               RS                       -3
# 349  BRASILEIRA NATA               RS                       -3
# 350  BRASILEIRA NATA               SP                       -3
# 351  BRASILEIRA NATA               SP                       -3
# 352  BRASILEIRA NATA               SP                       -3
#
#     NM_MUNICIPIO_NASCIMENTO DT_NASCIMENTO  NR_IDADE_DATA_POSSE  \
# 0                 FORTALEZA    04/02/1960                 62.0
# 1                  BRASÍLIA    16/01/1972                 50.0
# 2                   PALMELO    13/12/1970                 52.0
# 3                   LIMEIRA    26/10/1948                 74.0
# 4                CHAPADINHA    03/07/1957                 65.0
# ..                      ...           ...                  ...
# 348               SANANDUVA    13/11/1957                 65.0
# 349               SANANDUVA    13/11/1957                 65.0
# 350                  GUAÍRA    10/03/1955                 67.0
# 351                  GUAÍRA    10/03/1955                 67.0
# 352                  GUAÍRA    10/03/1955                 67.0
#
#      NR_TITULO_ELEITORAL_CANDIDATO  CD_GENERO  DS_GENERO  CD_GRAU_INSTRUCAO  \
# 0                      33809620736          2  MASCULINO                  8
# 1                       9788392054          4   FEMININO                  6
# 2                      68106251040          2  MASCULINO                  6
# 3                       3797321058          4   FEMININO                  4
# 4                       2147771171          2  MASCULINO                  8
# ..                             ...        ...        ...                ...
# 348                    11030061821          2  MASCULINO                  6
# 349                    11030061821          2  MASCULINO                  6
# 350                     4447512348          2  MASCULINO                  4
# 351                     4447512348          2  MASCULINO                  4
# 352                     4447512348          2  MASCULINO                  4
#
#                DS_GRAU_INSTRUCAO  CD_ESTADO_CIVIL DS_ESTADO_CIVIL  \
# 0              SUPERIOR COMPLETO                3       CASADO(A)
# 1          ENSINO MÉDIO COMPLETO                3       CASADO(A)
# 2          ENSINO MÉDIO COMPLETO                3       CASADO(A)
# 3    ENSINO FUNDAMENTAL COMPLETO                5        VIÚVO(A)
# 4              SUPERIOR COMPLETO                3       CASADO(A)
# ..                           ...              ...             ...
# 348        ENSINO MÉDIO COMPLETO                3       CASADO(A)
# 349        ENSINO MÉDIO COMPLETO                3       CASADO(A)
# 350  ENSINO FUNDAMENTAL COMPLETO                3       CASADO(A)
# 351  ENSINO FUNDAMENTAL COMPLETO                3       CASADO(A)
# 352  ENSINO FUNDAMENTAL COMPLETO                3       CASADO(A)
#
#      CD_COR_RACA DS_COR_RACA  CD_OCUPACAO DS_OCUPACAO  \
# 0              3       PARDA          257  EMPRESÁRIO
# 1              1      BRANCA          999      OUTROS
# 2              1      BRANCA          999      OUTROS
# 3              1      BRANCA          277    DEPUTADO
# 4              1      BRANCA          111      MÉDICO
# ..           ...         ...          ...         ...
# 348            1      BRANCA          257  EMPRESÁRIO
# 349            1      BRANCA          257  EMPRESÁRIO
# 350            1      BRANCA          277    DEPUTADO
# 351            1      BRANCA          277    DEPUTADO
# 352            1      BRANCA          277    DEPUTADO
#
#      VR_DESPESA_MAX_CAMPANHA  CD_SIT_TOT_TURNO DS_SIT_TOT_TURNO ST_REELEICAO  \
# 0               3,176,572.53                -1           #NULO#            N
# 1               1,270,629.01                -1           #NULO#            N
# 2               3,176,572.53                -1           #NULO#            N
# 3               3,176,572.53                -1           #NULO#            S
# 4               3,176,572.53                -1           #NULO#            N
# ..                       ...               ...              ...          ...
# 348             3,811,887.03                -1           #NULO#            N
# 349             3,811,887.03                -1           #NULO#            N
# 350             3,176,572.53                -1           #NULO#            N
# 351             3,176,572.53                -1           #NULO#            N
# 352             3,176,572.53                -1           #NULO#            N
#
#     ST_DECLARAR_BENS  NR_PROTOCOLO_CANDIDATURA          NR_PROCESSO  \
# 0                  S                        -1  6008878920226060000
# 1                  N                        -1  6007049120226070000
# 2                  S                        -1  6012742320226090000
# 3                  S                        -1  6013739020226090000
# 4                  S                        -1  6008375220226100000
# ..               ...                       ...                  ...
# 348                S                        -1  6007169420226110000
# 349                S                        -1  6007169420226110000
# 350                S                        -1  6004648520226220000
# 351                S                        -1  6004648520226220000
# 352                S                        -1  6004648520226220000
#
#      CD_SITUACAO_CANDIDATO_PLEITO DS_SITUACAO_CANDIDATO_PLEITO  \
# 0                              -1                       #NULO#
# 1                              -1                       #NULO#
# 2                              -1                       #NULO#
# 3                              -1                       #NULO#
# 4                              -1                       #NULO#
# ..                            ...                          ...
# 348                            -1                       #NULO#
# 349                            -1                       #NULO#
# 350                            -1                       #NULO#
# 351                            -1                       #NULO#
# 352                            -1                       #NULO#
#
#      CD_SITUACAO_CANDIDATO_URNA DS_SITUACAO_CANDIDATO_URNA  \
# 0                            -1                     #NULO#
# 1                            -1                     #NULO#
# 2                            -1                     #NULO#
# 3                            -1                     #NULO#
# 4                            -1                     #NULO#
# ..                          ...                        ...
# 348                          -1                     #NULO#
# 349                          -1                     #NULO#
# 350                          -1                     #NULO#
# 351                          -1                     #NULO#
# 352                          -1                     #NULO#
#
#     ST_CANDIDATO_INSERIDO_URNA NM_TIPO_DESTINACAO_VOTOS  \
# 0                          SIM                   #NULO#
# 1                          SIM                   #NULO#
# 2                          SIM                   #NULO#
# 3                          SIM                   #NULO#
# 4                          NÃO                   #NULO#
# ..                         ...                      ...
# 348                        SIM                   #NULO#
# 349                        SIM                   #NULO#
# 350                        SIM                   #NULO#
# 351                        SIM                   #NULO#
# 352                        SIM                   #NULO#
#
#      CD_SITUACAO_CANDIDATO_TOT DS_SITUACAO_CANDIDATO_TOT ST_PREST_CONTAS
# 0                           -1                    #NULO#               N
# 1                           -1                    #NULO#               N
# 2                           -1                    #NULO#               N
# 3                           -1                    #NULO#               N
# 4                           -1                    #NULO#               N
# ..                         ...                       ...             ...
# 348                         -1                    #NULO#               N
# 349                         -1                    #NULO#               N
# 350                         -1                    #NULO#               N
# 351                         -1                    #NULO#               N
# 352                         -1                    #NULO#               N
#
# [353 rows x 86 columns]

# %%
multas_candidatos.to_csv('multas_ambientais_candidatos_2022.csv', index=False)

# %%
# agora vamos olhar para os DOADORES de campanha. A fonte é o arquivo "receitas_candidatos_2022_BRASIL", também do TSE, que pode ser baixado aqui: https://dadosabertos.tse.jus.br/dataset/dadosabertos-tse-jus-br-dataset-prestacao-de-contas-eleitorais-2022)

doadores = pd.read_csv('/content/drive/MyDrive/ibama fines/receitas_candidatos_2022_BRASIL.csv', sep=';', encoding='latin1', converters={'NR_CPF_CANDIDATO': str, 'NR_CPF_CNPJ_DOADOR': str})

doadores.head(1)
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO  \
# 0  08/09/2022   02:02:04         2022                2       ORDINÁRIA
#
#    CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  ST_TURNO  \
# 0         546  Eleições Gerais Estaduais 2022  02/10/2022         1
#
#     TP_PRESTACAO_CONTAS DT_PRESTACAO_CONTAS  SQ_PRESTADOR_CONTAS SG_UF SG_UE  \
# 0  RELATÓRIO FINANCEIRO          29/08/2022           3785018833    SC    SC
#
#             NM_UE  NR_CNPJ_PRESTADOR_CONTA  CD_CARGO           DS_CARGO  \
# 0  SANTA CATARINA           47497012000137         7  Deputado Estadual
#
#    SQ_CANDIDATO  NR_CANDIDATO           NM_CANDIDATO NR_CPF_CANDIDATO  \
# 0  240001616185         44144  JAIME JOÃO PASQUALINI      29272947987
#
#    NR_CPF_VICE_CANDIDATO  NR_PARTIDO SG_PARTIDO    NM_PARTIDO  \
# 0                     -1          44      UNIÃO  UNIÃO BRASIL
#
#    CD_FONTE_RECEITA DS_FONTE_RECEITA  CD_ORIGEM_RECEITA  DS_ORIGEM_RECEITA  \
# 0                 1  OUTROS RECURSOS           10010100  Recursos próprios
#
#    CD_NATUREZA_RECEITA DS_NATUREZA_RECEITA  CD_ESPECIE_RECEITA  \
# 0                    1          FINANCEIRO                   1
#
#          DS_ESPECIE_RECEITA  CD_CNAE_DOADOR DS_CNAE_DOADOR NR_CPF_CNPJ_DOADOR  \
# 0  Transferência eletrônica              -1         #NULO#        29272947987
#
#                NM_DOADOR          NM_DOADOR_RFB CD_ESFERA_PARTIDARIA_DOADOR  \
# 0  JAIME JOÃO PASQUALINI  JAIME JOAO PASQUALINI                      #NULO#
#
#   DS_ESFERA_PARTIDARIA_DOADOR SG_UF_DOADOR  CD_MUNICIPIO_DOADOR  \
# 0                      #NULO#           SC                   -1
#
#   NM_MUNICIPIO_DOADOR  SQ_CANDIDATO_DOADOR  NR_CANDIDATO_DOADOR  \
# 0              #NULO#         240001616185                44144
#
#    CD_CARGO_CANDIDATO_DOADOR DS_CARGO_CANDIDATO_DOADOR  NR_PARTIDO_DOADOR  \
# 0                          7         Deputado Estadual                 44
#
#   SG_PARTIDO_DOADOR NM_PARTIDO_DOADOR       NR_RECIBO_DOACAO  \
# 0             UNIÃO      UNIÃO BRASIL  441440700000SC000001E
#
#   NR_DOCUMENTO_DOACAO  SQ_RECEITA  DT_RECEITA DS_RECEITA VR_RECEITA
# 0     600276000062313    20204582  21/08/2022     #NULO#    5000,00

# %%
multas_doadores = naonulos.merge(doadores, left_on='cpf_ou_cnpj', right_on='NR_CPF_CNPJ_DOADOR')

multas_doadores.head(3)
# Out:
#        n       tipo_infracao data_infracao bioma    estado     municipio  \
# 0  32834  Controle ambiental    2005-10-28   NaN  AMAZONAS  BOCA DO ACRE
# 1  23814               Flora    2005-10-28   NaN  AMAZONAS  BOCA DO ACRE
# 2  22785               Flora    2005-10-28   NaN  AMAZONAS  BOCA DO ACRE
#
#    cpf_ou_cnpj nome_autuado n_a.i. serie_a.i.  valor_multa  \
# 0  00915017253   JOSÉ LOPES  16937          D    226,500.0
# 1  00915017253   JOSÉ LOPES  16928          D    221,950.0
# 2  00915017253   JOSÉ LOPES  16934          D    213,900.0
#
#              n_processo status_debito  \
# 0  02005.002980/2005-83      Ajuizado
# 1  02005.002974/2005-26      Ajuizado
# 2  02005.002978/2005-12      Ajuizado
#
#                                  sancoes_aplicadas   ano  DT_GERACAO  \
# 0        70 Lei, 9605/98, 40 2º Decreto, 3179/1999  2005  08/09/2022
# 1    70 1º Lei, 9605/98, 40º 2º Decreto, 3179/1999  2005  08/09/2022
# 2  70 1º 50 Lei, 9605/98, 37 2º Decreto, 3179/1999  2005  08/09/2022
#
#   HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO  CD_ELEICAO  \
# 0   02:02:04         2022                2       ORDINÁRIA         546
# 1   02:02:04         2022                2       ORDINÁRIA         546
# 2   02:02:04         2022                2       ORDINÁRIA         546
#
#                        DS_ELEICAO  DT_ELEICAO  ST_TURNO   TP_PRESTACAO_CONTAS  \
# 0  Eleições Gerais Estaduais 2022  02/10/2022         1  RELATÓRIO FINANCEIRO
# 1  Eleições Gerais Estaduais 2022  02/10/2022         1  RELATÓRIO FINANCEIRO
# 2  Eleições Gerais Estaduais 2022  02/10/2022         1  RELATÓRIO FINANCEIRO
#
#   DT_PRESTACAO_CONTAS  SQ_PRESTADOR_CONTAS SG_UF SG_UE NM_UE  \
# 0          31/08/2022           3795991146    AC    AC  ACRE
# 1          31/08/2022           3795991146    AC    AC  ACRE
# 2          31/08/2022           3795991146    AC    AC  ACRE
#
#    NR_CNPJ_PRESTADOR_CONTA  CD_CARGO           DS_CARGO  SQ_CANDIDATO  \
# 0           47552912000130         7  Deputado Estadual   10001649330
# 1           47552912000130         7  Deputado Estadual   10001649330
# 2           47552912000130         7  Deputado Estadual   10001649330
#
#    NR_CANDIDATO       NM_CANDIDATO NR_CPF_CANDIDATO  NR_CPF_VICE_CANDIDATO  \
# 0         22345  JOSÉ LOPES JÚNIOR      68395884249                     -1
# 1         22345  JOSÉ LOPES JÚNIOR      68395884249                     -1
# 2         22345  JOSÉ LOPES JÚNIOR      68395884249                     -1
#
#    NR_PARTIDO SG_PARTIDO       NM_PARTIDO  CD_FONTE_RECEITA DS_FONTE_RECEITA  \
# 0          22         PL  Partido Liberal                 1  OUTROS RECURSOS
# 1          22         PL  Partido Liberal                 1  OUTROS RECURSOS
# 2          22         PL  Partido Liberal                 1  OUTROS RECURSOS
#
#    CD_ORIGEM_RECEITA            DS_ORIGEM_RECEITA  CD_NATUREZA_RECEITA  \
# 0           10010200  Recursos de pessoas físicas                    1
# 1           10010200  Recursos de pessoas físicas                    1
# 2           10010200  Recursos de pessoas físicas                    1
#
#   DS_NATUREZA_RECEITA  CD_ESPECIE_RECEITA        DS_ESPECIE_RECEITA  \
# 0          FINANCEIRO                   1  Transferência eletrônica
# 1          FINANCEIRO                   1  Transferência eletrônica
# 2          FINANCEIRO                   1  Transferência eletrônica
#
#    CD_CNAE_DOADOR DS_CNAE_DOADOR NR_CPF_CNPJ_DOADOR   NM_DOADOR NM_DOADOR_RFB  \
# 0              -1         #NULO#        00915017253  JOSE LOPES    JOSE LOPES
# 1              -1         #NULO#        00915017253  JOSE LOPES    JOSE LOPES
# 2              -1         #NULO#        00915017253  JOSE LOPES    JOSE LOPES
#
#   CD_ESFERA_PARTIDARIA_DOADOR DS_ESFERA_PARTIDARIA_DOADOR SG_UF_DOADOR  \
# 0                      #NULO#                      #NULO#       #NULO#
# 1                      #NULO#                      #NULO#       #NULO#
# 2                      #NULO#                      #NULO#       #NULO#
#
#    CD_MUNICIPIO_DOADOR NM_MUNICIPIO_DOADOR  SQ_CANDIDATO_DOADOR  \
# 0                   -1              #NULO#                   -1
# 1                   -1              #NULO#                   -1
# 2                   -1              #NULO#                   -1
#
#    NR_CANDIDATO_DOADOR  CD_CARGO_CANDIDATO_DOADOR DS_CARGO_CANDIDATO_DOADOR  \
# 0                   -1                         -1                    #NULO#
# 1                   -1                         -1                    #NULO#
# 2                   -1                         -1                    #NULO#
#
#    NR_PARTIDO_DOADOR SG_PARTIDO_DOADOR NM_PARTIDO_DOADOR  \
# 0                 -1            #NULO#            #NULO#
# 1                 -1            #NULO#            #NULO#
# 2                 -1            #NULO#            #NULO#
#
#         NR_RECIBO_DOACAO NR_DOCUMENTO_DOACAO  SQ_RECEITA  DT_RECEITA  \
# 0  223450700000AC000002E             9019037    20234168  30/08/2022
# 1  223450700000AC000002E             9019037    20234168  30/08/2022
# 2  223450700000AC000002E             9019037    20234168  30/08/2022
#
#   DS_RECEITA  VR_RECEITA
# 0     #NULO#    73,000.0
# 1     #NULO#    73,000.0
# 2     #NULO#    73,000.0

# %%
multas_doadores.to_csv('multas_ambientais_doadores.csv', index=False)

# %% [markdown]
# Agora vamos ver doadores e candidatos que já foram autuados por manter funcionários em situação análoga à escravidão. Fonte: [Ministério da Economia, via LAI, para a **Fiquem Sabendo**](https://fiquemsabendo.com.br/transparencia/autuados-por-trabalho-escravo-entre-2010-e-2020/)

# %%
trab_escravo = pd.read_excel('/content/drive/MyDrive/ibama fines/trab_escravo_com_nomes_cpfs.xlsx', skiprows=7)

trab_escravo.head(1)
# Out:
#     Ano  Operação                  Dia/Mês  UF              Município  \
# 0  2010         1  19/01/2010 a 29/01/2010  GO  MONTE ALEGRE DE GOIÁS
#
#       CNAE        Descrição CNAE             Proprietário  CNPJ/CEI/CPF  \
# 0  0151201  CRIAÇÃO DE BOVINOS P  THIAGO NEIVA HONORATO\n     330874152
#
#   Estabelecimento Inspecionado  Nº Trab. cond. analog escravo
# 0            FAZENDA JOÃO LUIZ                              3

# %%
# arrumando colunas
trab_escravo.columns = trab_escravo.columns.str.lower().str.replace(' ', '_')
trab_escravo.columns = trab_escravo.columns.str.replace('º', '')
trab_escravo.columns = trab_escravo.columns.str.replace('í', 'i')
trab_escravo.columns = trab_escravo.columns.str.replace('ã', 'a')
trab_escravo.columns = trab_escravo.columns.str.replace('é', 'e')
trab_escravo.columns = trab_escravo.columns.str.replace('ç', 'c')
trab_escravo.columns = trab_escravo.columns.str.replace('õ', 'o')

# %%
trab_escravo['cnpj/cei/cpf'] = trab_escravo['cnpj/cei/cpf'].astype(str)

# %%
trab_escravo['cnpj/cei/cpf'] = trab_escravo['cnpj/cei/cpf'].str.zfill(11)

# %%
doadores_trab_escravo = doadores.merge(trab_escravo, left_on='NR_CPF_CNPJ_DOADOR', right_on='cnpj/cei/cpf')
doadores_trab_escravo
# Out:
#     DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO  \
# 0   08/09/2022   02:02:04         2022                2       ORDINÁRIA
# 1   08/09/2022   02:02:04         2022                2       ORDINÁRIA
# 2   08/09/2022   02:02:04         2022                2       ORDINÁRIA
# 3   08/09/2022   02:02:04         2022                2       ORDINÁRIA
# 4   08/09/2022   02:02:04         2022                2       ORDINÁRIA
# 5   08/09/2022   02:02:04         2022                2       ORDINÁRIA
# 6   08/09/2022   02:02:04         2022                2       ORDINÁRIA
# 7   08/09/2022   02:02:04         2022                2       ORDINÁRIA
# 8   08/09/2022   02:02:04         2022                2       ORDINÁRIA
# 9   08/09/2022   02:02:04         2022                2       ORDINÁRIA
# 10  08/09/2022   02:02:04         2022                2       ORDINÁRIA
# 11  08/09/2022   02:02:04         2022                2       ORDINÁRIA
#
#     CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  ST_TURNO  \
# 0          546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 1          546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 2          546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 3          546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 4          546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 5          546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 6          544      Eleição Geral Federal 2022  02/10/2022         1
# 7          546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 8          546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 9          546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 10         546  Eleições Gerais Estaduais 2022  02/10/2022         1
# 11         546  Eleições Gerais Estaduais 2022  02/10/2022         1
#
#      TP_PRESTACAO_CONTAS DT_PRESTACAO_CONTAS  SQ_PRESTADOR_CONTAS SG_UF SG_UE  \
# 0   RELATÓRIO FINANCEIRO          31/08/2022           3795991146    AC    AC
# 1   RELATÓRIO FINANCEIRO          07/09/2022           3794801898    AC    AC
# 2   RELATÓRIO FINANCEIRO          05/09/2022           3764967876    PE    PE
# 3   RELATÓRIO FINANCEIRO          21/08/2022           3778706866    PE    PE
# 4   RELATÓRIO FINANCEIRO          18/08/2022           3778704181    PE    PE
# 5   RELATÓRIO FINANCEIRO          06/09/2022           3764967503    PA    PA
# 6   RELATÓRIO FINANCEIRO          03/09/2022           3786453275    BR    BR
# 7   RELATÓRIO FINANCEIRO          31/08/2022           3795991146    AC    AC
# 8   RELATÓRIO FINANCEIRO          28/08/2022           3797143332    RN    RN
# 9   RELATÓRIO FINANCEIRO          07/09/2022           3792549656    SP    SP
# 10  RELATÓRIO FINANCEIRO          26/08/2022           3771832871    MA    MA
# 11  RELATÓRIO FINANCEIRO          26/08/2022           3771832871    MA    MA
#
#                   NM_UE  NR_CNPJ_PRESTADOR_CONTA  CD_CARGO           DS_CARGO  \
# 0                  ACRE           47552912000130         7  Deputado Estadual
# 1                  ACRE           47547312000183         5            Senador
# 2            PERNAMBUCO           47422957000190         3         Governador
# 3            PERNAMBUCO           47464115000109         7  Deputado Estadual
# 4            PERNAMBUCO           47463946000158         6   Deputado Federal
# 5                  PARÁ           47423317000102         6   Deputado Federal
# 6                BRASIL           47508748000163         1         Presidente
# 7                  ACRE           47552912000130         7  Deputado Estadual
# 8   RIO GRANDE DO NORTE           47555046000130         6   Deputado Federal
# 9             SÃO PAULO           47533654000144         5            Senador
# 10             MARANHÃO           47448938000132         7  Deputado Estadual
# 11             MARANHÃO           47448938000132         7  Deputado Estadual
#
#     SQ_CANDIDATO  NR_CANDIDATO                            NM_CANDIDATO  \
# 0    10001649330         22345                       JOSÉ LOPES JÚNIOR
# 1    10001643706           222                  MARCIA ESPINOSA BITTAR
# 2   170001604111            44             MIGUEL DE SOUZA LEÃO COELHO
# 3   170001609285         44000            ANTONIO DE SOUZA LEAO COELHO
# 4   170001609122          4401  FERNANDO BEZERRA DE SOUZA COELHO FILHO
# 5   140001604551          4410                   JOELMA DE MOURA LEITE
# 6   280001618036            22                  JAIR MESSIAS BOLSONARO
# 7    10001649330         22345                       JOSÉ LOPES JÚNIOR
# 8   200001653694          1516            MARIA DO ROSARIO DE OLIVEIRA
# 9   250001639699           123             JOSÉ ALDO REBELO FIGUEIREDO
# 10  100001607077         40222        RAIMUNDO FLORÊNCIO MONTEIRO NETO
# 11  100001607077         40222        RAIMUNDO FLORÊNCIO MONTEIRO NETO
#
#    NR_CPF_CANDIDATO  NR_CPF_VICE_CANDIDATO  NR_PARTIDO SG_PARTIDO  \
# 0       68395884249                     -1          22         PL
# 1       31222285134            12951390220          22         PL
# 2       07096382488            84598948434          44      UNIÃO
# 3       09971514478                     -1          44      UNIÃO
# 4       04921093466                     -1          44      UNIÃO
# 5       82895015368                     -1          44      UNIÃO
# 6       45317828791            50021753768          22         PL
# 7       68395884249                     -1          22         PL
# 8       09058451453                     -1          15        MDB
# 9       16412150463            68170475872          12        PDT
# 10      01120716357                     -1          40        PSB
# 11      01120716357                     -1          40        PSB
#
#                           NM_PARTIDO  CD_FONTE_RECEITA DS_FONTE_RECEITA  \
# 0                    Partido Liberal                 1  OUTROS RECURSOS
# 1                    Partido Liberal                 1  OUTROS RECURSOS
# 2                       UNIÃO BRASIL                 1  OUTROS RECURSOS
# 3                       UNIÃO BRASIL                 1  OUTROS RECURSOS
# 4                       UNIÃO BRASIL                 1  OUTROS RECURSOS
# 5                       UNIÃO BRASIL                 1  OUTROS RECURSOS
# 6                    Partido Liberal                 1  OUTROS RECURSOS
# 7                    Partido Liberal                 1  OUTROS RECURSOS
# 8   Movimento Democrático Brasileiro                 1  OUTROS RECURSOS
# 9    Partido Democrático Trabalhista                 1  OUTROS RECURSOS
# 10     Partido Socialista Brasileiro                 1  OUTROS RECURSOS
# 11     Partido Socialista Brasileiro                 1  OUTROS RECURSOS
#
#     CD_ORIGEM_RECEITA            DS_ORIGEM_RECEITA  CD_NATUREZA_RECEITA  \
# 0            10010100            Recursos próprios                    1
# 1            10010200  Recursos de pessoas físicas                    1
# 2            10010200  Recursos de pessoas físicas                    1
# 3            10010200  Recursos de pessoas físicas                    1
# 4            10010200  Recursos de pessoas físicas                    1
# 5            10010200  Recursos de pessoas físicas                    1
# 6            10010200  Recursos de pessoas físicas                    1
# 7            10010200  Recursos de pessoas físicas                    1
# 8            10010200  Recursos de pessoas físicas                    1
# 9            10010200  Recursos de pessoas físicas                    1
# 10           10010200  Recursos de pessoas físicas                    0
# 11           10010200  Recursos de pessoas físicas                    0
#
#    DS_NATUREZA_RECEITA  CD_ESPECIE_RECEITA        DS_ESPECIE_RECEITA  \
# 0           FINANCEIRO                   1  Transferência eletrônica
# 1           FINANCEIRO                   1  Transferência eletrônica
# 2           FINANCEIRO                   1  Transferência eletrônica
# 3           FINANCEIRO                   1  Transferência eletrônica
# 4           FINANCEIRO                   1  Transferência eletrônica
# 5           FINANCEIRO                   1  Transferência eletrônica
# 6           FINANCEIRO                   1  Transferência eletrônica
# 7           FINANCEIRO                   1  Transferência eletrônica
# 8           FINANCEIRO                  19                       PIX
# 9           FINANCEIRO                   1  Transferência eletrônica
# 10           ESTIMÁVEL                   2                  Estimado
# 11           ESTIMÁVEL                   2                  Estimado
#
#     CD_CNAE_DOADOR DS_CNAE_DOADOR NR_CPF_CNPJ_DOADOR  \
# 0               -1         #NULO#        68395884249
# 1               -1         #NULO#        68395884249
# 2               -1         #NULO#        09655298191
# 3               -1         #NULO#        09655298191
# 4               -1         #NULO#        09655298191
# 5               -1         #NULO#        06112960125
# 6               -1         #NULO#        28236092291
# 7               -1         #NULO#        00915017253
# 8               -1         #NULO#        36841323904
# 9               -1         #NULO#        15678881604
# 10              -1         #NULO#        15920895268
# 11              -1         #NULO#        15920895268
#
#                            NM_DOADOR                     NM_DOADOR_RFB  \
# 0                  JOSE LOPES JUNIOR                 JOSE LOPES JUNIOR
# 1                  JOSE LOPES JUNIOR                 JOSE LOPES JUNIOR
# 2          EMIVAL RAMOS CAIADO FILHO         EMIVAL RAMOS CAIADO FILHO
# 3          EMIVAL RAMOS CAIADO FILHO         EMIVAL RAMOS CAIADO FILHO
# 4          EMIVAL RAMOS CAIADO FILHO         EMIVAL RAMOS CAIADO FILHO
# 5   CARLOS GILBERTO OLIVEIRA BARRETO  CARLOS GILBERTO OLIVEIRA BARRETO
# 6         HILDEFONSO DE ABREU ARAUJO        HILDEFONSO DE ABREU ARAUJO
# 7                         JOSE LOPES                        JOSE LOPES
# 8     JOÃO ALTAIR CAETANO DOS SANTOS    JOAO ALTAIR CAETANO DOS SANTOS
# 9            SERGIO AUGUSTO A. BRAGA   SERGIO AUGUSTO DE ALMEIDA BRAGA
# 10        JOSE CARLOS NOBRE MONTEIRO        JOSE CARLOS NOBRE MONTEIRO
# 11        JOSE CARLOS NOBRE MONTEIRO        JOSE CARLOS NOBRE MONTEIRO
#
#    CD_ESFERA_PARTIDARIA_DOADOR DS_ESFERA_PARTIDARIA_DOADOR SG_UF_DOADOR  \
# 0                       #NULO#                      #NULO#           AC
# 1                       #NULO#                      #NULO#       #NULO#
# 2                       #NULO#                      #NULO#       #NULO#
# 3                       #NULO#                      #NULO#       #NULO#
# 4                       #NULO#                      #NULO#       #NULO#
# 5                       #NULO#                      #NULO#       #NULO#
# 6                       #NULO#                      #NULO#       #NULO#
# 7                       #NULO#                      #NULO#       #NULO#
# 8                       #NULO#                      #NULO#       #NULO#
# 9                       #NULO#                      #NULO#       #NULO#
# 10                      #NULO#                      #NULO#       #NULO#
# 11                      #NULO#                      #NULO#       #NULO#
#
#     CD_MUNICIPIO_DOADOR NM_MUNICIPIO_DOADOR  SQ_CANDIDATO_DOADOR  \
# 0                    -1              #NULO#          10001649330
# 1                    -1              #NULO#                   -1
# 2                    -1              #NULO#                   -1
# 3                    -1              #NULO#                   -1
# 4                    -1              #NULO#                   -1
# 5                    -1              #NULO#                   -1
# 6                    -1              #NULO#                   -1
# 7                    -1              #NULO#                   -1
# 8                    -1              #NULO#                   -1
# 9                    -1              #NULO#                   -1
# 10                   -1              #NULO#                   -1
# 11                   -1              #NULO#                   -1
#
#     NR_CANDIDATO_DOADOR  CD_CARGO_CANDIDATO_DOADOR DS_CARGO_CANDIDATO_DOADOR  \
# 0                 22345                          7         Deputado Estadual
# 1                    -1                         -1                    #NULO#
# 2                    -1                         -1                    #NULO#
# 3                    -1                         -1                    #NULO#
# 4                    -1                         -1                    #NULO#
# 5                    -1                         -1                    #NULO#
# 6                    -1                         -1                    #NULO#
# 7                    -1                         -1                    #NULO#
# 8                    -1                         -1                    #NULO#
# 9                    -1                         -1                    #NULO#
# 10                   -1                         -1                    #NULO#
# 11                   -1                         -1                    #NULO#
#
#     NR_PARTIDO_DOADOR SG_PARTIDO_DOADOR NM_PARTIDO_DOADOR  \
# 0                  22                PL   Partido Liberal
# 1                  -1            #NULO#            #NULO#
# 2                  -1            #NULO#            #NULO#
# 3                  -1            #NULO#            #NULO#
# 4                  -1            #NULO#            #NULO#
# 5                  -1            #NULO#            #NULO#
# 6                  -1            #NULO#            #NULO#
# 7                  -1            #NULO#            #NULO#
# 8                  -1            #NULO#            #NULO#
# 9                  -1            #NULO#            #NULO#
# 10                 -1            #NULO#            #NULO#
# 11                 -1            #NULO#            #NULO#
#
#          NR_RECIBO_DOACAO NR_DOCUMENTO_DOACAO  SQ_RECEITA  DT_RECEITA  \
# 0   223450700000AC000001E         68395884249    20234167  18/08/2022
# 1   002220500000AC000001E               81901    20322303  19/08/2022
# 2   000440300000PE000001E           234488355    20282071  16/08/2022
# 3   440000700000PE000001E           234489377    20157776  16/08/2022
# 4   044010600000PE000001E           234488890    20146956  16/08/2022
# 5   044100600000PA000003E                  47    20296983  05/09/2022
# 6                  #NULO#     521342000015245    20272073  29/08/2022
# 7   223450700000AC000002E             9019037    20234168  30/08/2022
# 8                  #NULO#             0829901    20203770  26/08/2022
# 9   001230500000SP000022E             8557772    20316756  06/09/2022
# 10  402220700000MA000003E              #NULO#    20186126  16/08/2022
# 11  402220700000MA000001E              #NULO#    20186125  16/08/2022
#
#                                            DS_RECEITA  VR_RECEITA  \
# 0                                              #NULO#   127,000.0
# 1                                              #NULO#   500,000.0
# 2                                              #NULO#   250,000.0
# 3                                              #NULO#   150,000.0
# 4                                              #NULO#   200,000.0
# 5                                              #NULO#    95,000.0
# 6                                              #NULO#     1,000.0
# 7                                              #NULO#    73,000.0
# 8                                              #NULO#       200.0
# 9                                              #NULO#    15,000.0
# 10  JEEP/CMAPASS LONGTUDE ANO/MOD 2021/2021 RENAVA...    12,000.0
# 11  CHEVROLET/S10 LTZ DD4A ANO/MOD 2020/2020 RENAV...    15,000.0
#
#    tres_primeiros dois_ultimos asteriscos cpf_mascarado tres_primeiros_nome  \
# 0             683           49     ******   683******49                 JOS
# 1             683           49     ******   683******49                 JOS
# 2             096           91     ******   096******91                 EMI
# 3             096           91     ******   096******91                 EMI
# 4             096           91     ******   096******91                 EMI
# 5             061           25     ******   061******25                 CAR
# 6             282           91     ******   282******91                 HIL
# 7             009           53     ******   009******53                 JOS
# 8             368           04     ******   368******04                 JOA
# 9             156           04     ******   156******04                 SER
# 10            159           68     ******   159******68                 JOS
# 11            159           68     ******   159******68                 JOS
#
#    dois_ultimos_nome asteriscos_nome nome_mascarado   ano  operacao  \
# 0                 OR          ******    JOS******OR  2012        56
# 1                 OR          ******    JOS******OR  2012        56
# 2                 HO          ******    EMI******HO  2010         1
# 3                 HO          ******    EMI******HO  2010         1
# 4                 HO          ******    EMI******HO  2010         1
# 5                 TO          ******    CAR******TO  2010        56
# 6                 JO          ******    HIL******JO  2012         7
# 7                 ES          ******    JOS******ES  2012        56
# 8                 OS          ******    JOA******OS  2010         8
# 9                 GA          ******    SER******GA  2010        31
# 10                RO          ******    JOS******RO  2016        25
# 11                RO          ******    JOS******RO  2016        25
#
#                     dia/mês  uf             municipio     cnae  \
# 0   17/07/2012 a 28/07/2012  AM          BOCA DO ACRE  0151201
# 1   17/07/2012 a 28/07/2012  AM          BOCA DO ACRE  0151201
# 2   19/01/2010 a 29/01/2010  TO            NATIVIDADE  0151201
# 3   19/01/2010 a 29/01/2010  TO            NATIVIDADE  0151201
# 4   19/01/2010 a 29/01/2010  TO            NATIVIDADE  0151201
# 5   15/06/2010 a 26/06/2010  PA  ELDORADO DOS CARAJÁS  0151203
# 6   06/02/2012 a 18/02/2012  PA       ABEL FIGUEIREDO  0151203
# 7   17/07/2012 a 28/07/2012  AM          BOCA DO ACRE  0151201
# 8   02/03/2010 a 08/03/2010  RO           PORTO VELHO  0151201
# 9   13/05/2010 a 21/05/2010  PA    ÁGUA AZUL DO NORTE  0151201
# 10  18/04/2016 a 27/05/2016  MA             PARNARAMA  0151203
# 11  18/04/2016 a 27/05/2016  MA             PARNARAMA  0151203
#
#           descricao_cnae                       proprietário cnpj/cei/cpf  \
# 0   CRIAÇÃO DE BOVINOS P                  JOSÉ LOPES JÚNIOR  68395884249
# 1   CRIAÇÃO DE BOVINOS P                  JOSÉ LOPES JÚNIOR  68395884249
# 2   CRIAÇÃO DE BOVINOS P        EMIVAL RAMOS CAIADO FILHO\n  09655298191
# 3   CRIAÇÃO DE BOVINOS P        EMIVAL RAMOS CAIADO FILHO\n  09655298191
# 4   CRIAÇÃO DE BOVINOS P        EMIVAL RAMOS CAIADO FILHO\n  09655298191
# 5   CRIAÇÃO DE BOVINOS,   CARLOS GILBERTO OLIVEIRA BARRETO   06112960125
# 6   CRIAÇÃO DE BOVINOS,          HIDELFONSO DE ABREU ARAÚJO  28236092291
# 7   CRIAÇÃO DE BOVINOS P                         JOSÉ LOPES  00915017253
# 8   CRIAÇÃO DE BOVINOS P   JOÃO ALTAIR CAETANO DOS SANTOS\n  36841323904
# 9   CRIAÇÃO DE BOVINOS P      SÉRGIO AUGUSTO ALMEIDA BRAGA   15678881604
# 10  CRIAÇÃO DE BOVINOS,         JOSÉ CARLOS NOBRE MONTEIRO   15920895268
# 11  CRIAÇÃO DE BOVINOS,         JOSÉ CARLOS NOBRE MONTEIRO   15920895268
#
#               estabelecimento_inspecionado  n_trab._cond._analog_escravo
# 0            FAZENDA MUSTAFA E FAZENDA FAM                            26
# 1            FAZENDA MUSTAFA E FAZENDA FAM                            26
# 2                     FAZENDA SANTA MÔNICA                            26
# 3                     FAZENDA SANTA MÔNICA                            26
# 4                     FAZENDA SANTA MÔNICA                            26
# 5   FAZENDA ESTRELA DO SUL (FAZ. OLIVENSE)                             2
# 6                       FAZENDA VALE VERDE                            11
# 7          FAZENDAS F38, FG E CACHOEIRINHA                            34
# 8                  FAZENDA RANCHO COLORADO                             8
# 9                            FAZENDA UNIÃO                            32
# 10                       FAZENDA TREMENDAL                             9
# 11                       FAZENDA TREMENDAL                             9

# %%
candidatos_trab_escravo = cand22.merge(trab_escravo, left_on='NR_CPF_CANDIDATO', right_on='cnpj/cei/cpf')
candidatos_trab_escravo
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  08/09/2022   13:05:22         2022                2  ELEIÇÃO ORDINÁRIA
# 1  08/09/2022   13:05:22         2022                2  ELEIÇÃO ORDINÁRIA
#
#    NR_TURNO  CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  \
# 0         1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 1         1         546  Eleições Gerais Estaduais 2022  02/10/2022
#
#   TP_ABRANGENCIA SG_UF SG_UE NM_UE  CD_CARGO           DS_CARGO  SQ_CANDIDATO  \
# 0       ESTADUAL    AC    AC  ACRE         7  DEPUTADO ESTADUAL   10001649330
# 1       ESTADUAL    PA    PA  PARÁ         7  DEPUTADO ESTADUAL  140001601812
#
#    NR_CANDIDATO            NM_CANDIDATO NM_URNA_CANDIDATO NM_SOCIAL_CANDIDATO  \
# 0         22345       JOSE LOPES JUNIOR          ZÉ LOPES              #NULO#
# 1         22963  JEANNE FARIAS DE BRITO      JEANNE BRITO              #NULO#
#
#   NR_CPF_CANDIDATO        NM_EMAIL  CD_SITUACAO_CANDIDATURA  \
# 0      68395884249  NÃO DIVULGÁVEL                       12
# 1      11648236200  NÃO DIVULGÁVEL                        3
#
#   DS_SITUACAO_CANDIDATURA  CD_DETALHE_SITUACAO_CAND DS_DETALHE_SITUACAO_CAND  \
# 0                    APTO                         2                 DEFERIDO
# 1                  INAPTO                        14               INDEFERIDO
#
#      TP_AGREMIACAO  NR_PARTIDO SG_PARTIDO       NM_PARTIDO  NR_FEDERACAO  \
# 0  PARTIDO ISOLADO          22         PL  PARTIDO LIBERAL            -1
# 1  PARTIDO ISOLADO          22         PL  PARTIDO LIBERAL            -1
#
#   NM_FEDERACAO SG_FEDERACAO DS_COMPOSICAO_FEDERACAO  SQ_COLIGACAO  \
# 0       #NULO#       #NULO#                  #NULO#   10001683275
# 1       #NULO#       #NULO#                  #NULO#  140001681129
#
#       NM_COLIGACAO DS_COMPOSICAO_COLIGACAO  CD_NACIONALIDADE DS_NACIONALIDADE  \
# 0  PARTIDO ISOLADO                      PL                 1  BRASILEIRA NATA
# 1  PARTIDO ISOLADO                      PL                 1  BRASILEIRA NATA
#
#   SG_UF_NASCIMENTO  CD_MUNICIPIO_NASCIMENTO NM_MUNICIPIO_NASCIMENTO  \
# 0               AM                       -3                  MANAUS
# 1               BA                       -3              ITAPETINGA
#
#   DT_NASCIMENTO  NR_IDADE_DATA_POSSE  NR_TITULO_ELEITORAL_CANDIDATO  \
# 0    07/12/1981                 41.0                    20565922259
# 1    26/10/1961                 61.0                     5092791350
#
#    CD_GENERO  DS_GENERO  CD_GRAU_INSTRUCAO      DS_GRAU_INSTRUCAO  \
# 0          2  MASCULINO                  8      SUPERIOR COMPLETO
# 1          4   FEMININO                  6  ENSINO MÉDIO COMPLETO
#
#    CD_ESTADO_CIVIL DS_ESTADO_CIVIL  CD_COR_RACA DS_COR_RACA  CD_OCUPACAO  \
# 0                1     SOLTEIRO(A)            1      BRANCA          131
# 1                1     SOLTEIRO(A)            2       PRETA          257
#
#   DS_OCUPACAO  VR_DESPESA_MAX_CAMPANHA  CD_SIT_TOT_TURNO DS_SIT_TOT_TURNO  \
# 0    ADVOGADO             1,270,629.01                -1           #NULO#
# 1  EMPRESÁRIO             1,270,629.01                -1           #NULO#
#
#   ST_REELEICAO ST_DECLARAR_BENS  NR_PROTOCOLO_CANDIDATURA  \
# 0            N                S                        -1
# 1            N                S                        -1
#
#            NR_PROCESSO  CD_SITUACAO_CANDIDATO_PLEITO  \
# 0  6006084420226010000                            -1
# 1  6003766920226140000                            -1
#
#   DS_SITUACAO_CANDIDATO_PLEITO  CD_SITUACAO_CANDIDATO_URNA  \
# 0                       #NULO#                          -1
# 1                       #NULO#                          -1
#
#   DS_SITUACAO_CANDIDATO_URNA ST_CANDIDATO_INSERIDO_URNA  \
# 0                     #NULO#                        SIM
# 1                     #NULO#                        NÃO
#
#   NM_TIPO_DESTINACAO_VOTOS  CD_SITUACAO_CANDIDATO_TOT  \
# 0                   #NULO#                         -1
# 1                   #NULO#                         -1
#
#   DS_SITUACAO_CANDIDATO_TOT ST_PREST_CONTAS tres_primeiros dois_ultimos  \
# 0                    #NULO#               N            683           49
# 1                    #NULO#               N            116           00
#
#   asteriscos cpf_mascarado tres_primeiros_nome dois_ultimos_nome  \
# 0     ******   683******49                 JOS                OR
# 1     ******   116******00                 JEA                TO
#
#   asteriscos_nome nome_mascarado   ano  operacao                  dia/mês  uf  \
# 0          ******    JOS******OR  2012        56  17/07/2012 a 28/07/2012  AM
# 1          ******    JEA******TO  2013        93  08/10/2013 a 18/10/2013  PA
#
#       municipio     cnae        descricao_cnae            proprietário  \
# 0  BOCA DO ACRE  0151201  CRIAÇÃO DE BOVINOS P       JOSÉ LOPES JÚNIOR
# 1        PACAJÁ  0151201  CRIAÇÃO DE BOVINOS P  JEANNE FARIAS DE BRITO
#
#   cnpj/cei/cpf   estabelecimento_inspecionado  n_trab._cond._analog_escravo
# 0  68395884249  FAZENDA MUSTAFA E FAZENDA FAM                            26
# 1  11648236200              FAZENDA ESCORPIÃO                             2
